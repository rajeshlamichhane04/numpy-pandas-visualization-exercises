# %%
from env import host, username, password
import pandas as pd
import numpy as np
from pydataset import data

# %%
# 3.Create a function named get_db_url. It should accept a username, hostname, password, and database name and return a url connection string formatted like in the example at the start of this lesson. 


def get_db_url_local(username, host, password, db_name):
    url = f'mysql+pymysql://{username}:{password}@{host}/{db_name}'
    return url

# %%
#4 Use your function to obtain a connection to the employees database.
db_name = "employees"
url = get_db_url_local(username, host, password, db_name)

# %%
employees = pd.read_sql('SELECT * FROM employees' , url)
employees
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12
# ...        ...         ...        ...       ...    ...         ...
# 300019  499995  1958-09-24     Dekang  Lichtner      F  1993-01-12
# 300020  499996  1953-03-07       Zito      Baaz      M  1990-09-27
# 300021  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 300022  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 300023  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
# [300024 rows x 6 columns]

# %%
#5. Once you have successfully run a query:
#a. Intentionally make a typo in the database url. What kind of error message do you see?
typo_url = get_db_url_local(username, host, password, "employes")

pd.read_sql('SELECT * FROM employees LIMIT 5', typo_url)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File /usr/local/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3256, in Engine._wrap_pool_connect(self, fn, connection)
#    3255 try:
# -> 3256     return fn()
#    3257 except dialect.dbapi.Error as e:
#
# File /usr/local/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py:310, in Pool.connect(self)
#     303 """Return a DBAPI connection from the pool.
#     304
#     305 The connection is instrumented such that when its
#    (...)
#     308
#     309 """
# --> 310 return _ConnectionFairy._checkout(self)
#
# File /usr/local/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py:868, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     867 if not fairy:
# --> 868     fairy = _ConnectionRecord.checkout(pool)
#     870     fairy._pool = pool
#
# ...

# %%
# access is denied

# %%
# b. Intentionally make an error in your SQL query. What does the error message look like?
url = get_db_url_local(username, host, password, "employees")

pd.read_sql('SELECT * FRO employees LIMIT 5', url)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File /usr/local/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1808, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1807     if not evt_handled:
# -> 1808         self.dialect.do_execute(
#    1809             cursor, statement, parameters, context
#    1810         )
#    1812 if self._has_events or self.engine._has_events:
#
# File /usr/local/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# File /usr/local/anaconda3/lib/python3.9/site-packages/pymysql/cursors.py:148, in Cursor.execute(self, query, args)
# ...

# %%
#no file is found

# %%
# 6. Read the employees and titles tables into two separate DataFrames.
employees
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12
# ...        ...         ...        ...       ...    ...         ...
# 300019  499995  1958-09-24     Dekang  Lichtner      F  1993-01-12
# 300020  499996  1953-03-07       Zito      Baaz      M  1990-09-27
# 300021  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 300022  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 300023  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
# [300024 rows x 6 columns]

# %%
titles = pd.read_sql('SELECT * FROM titles', url)
titles
# Out:
#         emp_no            title   from_date     to_date
# 0        10001  Senior Engineer  1986-06-26  9999-01-01
# 1        10002            Staff  1996-08-03  9999-01-01
# 2        10003  Senior Engineer  1995-12-03  9999-01-01
# 3        10004         Engineer  1986-12-01  1995-12-01
# 4        10004  Senior Engineer  1995-12-01  9999-01-01
# ...        ...              ...         ...         ...
# 443303  499997         Engineer  1987-08-30  1992-08-29
# 443304  499997  Senior Engineer  1992-08-29  9999-01-01
# 443305  499998     Senior Staff  1998-12-27  9999-01-01
# 443306  499998            Staff  1993-12-27  1998-12-27
# 443307  499999         Engineer  1997-11-30  9999-01-01
#
# [443308 rows x 4 columns]

# %%
# Read the employees and titles tables into two separate DataFrames.

employees.shape
# Out:
# (300024, 6)

# %%
titles.shape
# Out:
# (443308, 4)

# %%
# Display the summary statistics for each DataFrame.
employees.describe()
# Out:
#               emp_no
# count  300024.000000
# mean   253321.763392
# std    161828.235540
# min     10001.000000
# 25%     85006.750000
# 50%    249987.500000
# 75%    424993.250000
# max    499999.000000

# %%
titles.describe()
# Out:
#               emp_no
# count  443308.000000
# mean   253075.034430
# std    161853.292613
# min     10001.000000
# 25%     84855.750000
# 50%    249847.500000
# 75%    424891.250000
# max    499999.000000

# %%
#9. How many unique titles are in the titles DataFrame?

print(titles.title.value_counts())
print(f'unique titles {titles.title.unique().size}')
# Out:
# Engineer              115003
# Staff                 107391
# Senior Engineer        97750
# Senior Staff           92853
# Technique Leader       15159
# Assistant Engineer     15128
# Manager                   24
# Name: title, dtype: int64
# unique titles 7

# %%
# 10. What is the oldest date in the to_date column?

titles[["to_date"]].sort_values(by = "to_date").head(1)
# Out:
#           to_date
# 16064  1985-03-01

# %%
# 11. What is the most recent date in the to_date column?
titles[["to_date"]].max()
# Out:
# to_date    9999-01-01
# dtype: object

# %%
#Exercises II
#1 Copy the users and roles DataFrames from the examples above.

users = pd.DataFrame({
    'id': [1, 2, 3, 4, 5, 6],
    'name': ['bob', 'joe', 'sally', 'adam', 'jane', 'mike'],
    'role_id': [1, 2, 3, 3, np.nan, np.nan]
})
users
# Out:
#    id   name  role_id
# 0   1    bob      1.0
# 1   2    joe      2.0
# 2   3  sally      3.0
# 3   4   adam      3.0
# 4   5   jane      NaN
# 5   6   mike      NaN

# %%
roles = pd.DataFrame({
    'id': [1, 2, 3, 4],
    'name': ['admin', 'author', 'reviewer', 'commenter']
})
roles
# Out:
#    id       name
# 0   1      admin
# 1   2     author
# 2   3   reviewer
# 3   4  commenter

# %%
#2. What is the result of using a right join on the DataFrames?
users.merge(roles, left_on='role_id',right_on='id', how ='right', indicator = True)
# Out:
#    id_x name_x  role_id  id_y     name_y      _merge
# 0   1.0    bob      1.0     1      admin        both
# 1   2.0    joe      2.0     2     author        both
# 2   3.0  sally      3.0     3   reviewer        both
# 3   4.0   adam      3.0     3   reviewer        both
# 4   NaN    NaN      NaN     4  commenter  right_only

# %%
#3. What is the result of using an outer join on the DataFrames?
users.merge(roles, left_on = 'role_id', right_on ='id', how = 'outer', indicator = True)
# Out:
#    id_x name_x  role_id  id_y     name_y      _merge
# 0   1.0    bob      1.0   1.0      admin        both
# 1   2.0    joe      2.0   2.0     author        both
# 2   3.0  sally      3.0   3.0   reviewer        both
# 3   4.0   adam      3.0   3.0   reviewer        both
# 4   5.0   jane      NaN   NaN        NaN   left_only
# 5   6.0   mike      NaN   NaN        NaN   left_only
# 6   NaN    NaN      NaN   4.0  commenter  right_only

# %%
#4. What happens if you drop the foreign keys from the DataFrames and try to merge them?

users.merge(roles, left_on ='role_id', right_on = 'id', how = 'outer').drop(columns='role_id')
# Out:
#    id_x name_x  id_y     name_y
# 0   1.0    bob   1.0      admin
# 1   2.0    joe   2.0     author
# 2   3.0  sally   3.0   reviewer
# 3   4.0   adam   3.0   reviewer
# 4   5.0   jane   NaN        NaN
# 5   6.0   mike   NaN        NaN
# 6   NaN    NaN   4.0  commenter

# %%
# 5. Load the mpg dataset from PyDataset.

mpg=data('mpg')
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %%
#6. Output and read the documentation for the mpg dataset.

data('mpg',show_doc = True)
# Out:
# mpg
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Fuel economy data from 1999 and 2008 for 38 popular models of car
#
# ### Description
#
# This dataset contains a subset of the fuel economy data that the EPA makes
# available on http://fueleconomy.gov. It contains only models which had a new
# release every year between 1999 and 2008 - this was used as a proxy for the
# popularity of the car.
#
# ### Usage
#
#     data(mpg)
#
# ### Format
#
# A data frame with 234 rows and 11 variables
#
# ### Details
#
#   * manufacturer.
#
#   * model.
#
#   * displ. engine displacement, in litres
#
#   * year.
#
#   * cyl. number of cylinders
#
#   * trans. type of transmission
#
#   * drv. f = front-wheel drive, r = rear wheel drive, 4 = 4wd
#
#   * cty. city miles per gallon
#
#   * hwy. highway miles per gallon
#
#   * fl.
#
#   * class.

# %%
#7. How many rows and columns are in the dataset?

mpg.shape
# Out:
# (234, 11)

# %%
# 8. Check out your column names and perform any cleanup you may want on them.

mpg.columns
# Out:
# Index(['manufacturer', 'model', 'displ', 'year', 'cyl', 'trans', 'drv', 'cty',
#        'hwy', 'fl', 'class'],
#       dtype='object')

# %%
mpg.rename(columns={'displ':'display','cyl':'cylinder','trans':'transmission','drv':'drive','cty':'city','hwy':'highway'}, inplace = True)

mpg
# Out:
#     manufacturer   model  display  year  cylinder transmission drive  city  \
# 1           audi      a4      1.8  1999         4     auto(l5)     f    18
# 2           audi      a4      1.8  1999         4   manual(m5)     f    21
# 3           audi      a4      2.0  2008         4   manual(m6)     f    20
# 4           audi      a4      2.0  2008         4     auto(av)     f    21
# 5           audi      a4      2.8  1999         6     auto(l5)     f    16
# ..           ...     ...      ...   ...       ...          ...   ...   ...
# 230   volkswagen  passat      2.0  2008         4     auto(s6)     f    19
# 231   volkswagen  passat      2.0  2008         4   manual(m6)     f    21
# 232   volkswagen  passat      2.8  1999         6     auto(l5)     f    16
# 233   volkswagen  passat      2.8  1999         6   manual(m5)     f    18
# 234   volkswagen  passat      3.6  2008         6     auto(s6)     f    17
#
#      highway fl    class
# 1         29  p  compact
# ...

# %%
#9. Display the summary statistics for the dataset.
mpg.describe()
# Out:
#           display         year    cylinder        city     highway
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %%
#10. How many different manufacturers are there?

#len(mpg.manufacturer.value_counts())
mpg.manufacturer.nunique()
# Out:
# 15

# %%
#11. How many different models are there?

mpg.model.nunique()
# Out:
# 38

# %%
#12. Create a column named mileage_difference like you did in the DataFrames exercises; this column should contain the difference between highway and city mileage for each car

mpg.mileage_difference = mpg.highway - mpg.city
mpg
# Out:
# /var/folders/yt/n2syrxfn78lfgkf_dg2j4tj80000gn/T/ipykernel_883/1331948969.py:3: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   mpg.mileage_difference = mpg.highway - mpg.city
#     manufacturer   model  display  year  cylinder transmission drive  city  \
# 1           audi      a4      1.8  1999         4     auto(l5)     f    18
# 2           audi      a4      1.8  1999         4   manual(m5)     f    21
# 3           audi      a4      2.0  2008         4   manual(m6)     f    20
# 4           audi      a4      2.0  2008         4     auto(av)     f    21
# 5           audi      a4      2.8  1999         6     auto(l5)     f    16
# ..           ...     ...      ...   ...       ...          ...   ...   ...
# 230   volkswagen  passat      2.0  2008         4     auto(s6)     f    19
# 231   volkswagen  passat      2.0  2008         4   manual(m6)     f    21
# ...

# %%
#13. Create a column named average_mileage like you did in the DataFrames exercises; this is the mean of the city and highway mileage.
mpg["average_mileage"] = mpg[["city", "highway" ]].mean(axis=1)
mpg
# Out:
#     manufacturer   model  display  year  cylinder transmission drive  city  \
# 1           audi      a4      1.8  1999         4     auto(l5)     f    18
# 2           audi      a4      1.8  1999         4   manual(m5)     f    21
# 3           audi      a4      2.0  2008         4   manual(m6)     f    20
# 4           audi      a4      2.0  2008         4     auto(av)     f    21
# 5           audi      a4      2.8  1999         6     auto(l5)     f    16
# ..           ...     ...      ...   ...       ...          ...   ...   ...
# 230   volkswagen  passat      2.0  2008         4     auto(s6)     f    19
# 231   volkswagen  passat      2.0  2008         4   manual(m6)     f    21
# 232   volkswagen  passat      2.8  1999         6     auto(l5)     f    16
# 233   volkswagen  passat      2.8  1999         6   manual(m5)     f    18
# 234   volkswagen  passat      3.6  2008         6     auto(s6)     f    17
#
#      highway fl    class  average_mileage
# ...

# %%
# 14. Create a new column on the mpg dataset named is_automatic that holds boolean values denoting whether the car has an automatic transmission.
mpg["is_automatic"] = mpg.transmission.str.contains("auto")
mpg
# Out:
#     manufacturer   model  display  year  cylinder transmission drive  city  \
# 1           audi      a4      1.8  1999         4     auto(l5)     f    18
# 2           audi      a4      1.8  1999         4   manual(m5)     f    21
# 3           audi      a4      2.0  2008         4   manual(m6)     f    20
# 4           audi      a4      2.0  2008         4     auto(av)     f    21
# 5           audi      a4      2.8  1999         6     auto(l5)     f    16
# ..           ...     ...      ...   ...       ...          ...   ...   ...
# 230   volkswagen  passat      2.0  2008         4     auto(s6)     f    19
# 231   volkswagen  passat      2.0  2008         4   manual(m6)     f    21
# 232   volkswagen  passat      2.8  1999         6     auto(l5)     f    16
# 233   volkswagen  passat      2.8  1999         6   manual(m5)     f    18
# 234   volkswagen  passat      3.6  2008         6     auto(s6)     f    17
#
#      highway fl    class  average_mileage  is_automatic
# ...

# %%
#15. Using the mpg dataset, find out which which manufacturer has the best miles per gallon on average?
mpg.groupby(["manufacturer"]).average_mileage.mean().sort_values(ascending = False)
# Out:
# manufacturer
# honda         28.500000
# volkswagen    25.074074
# hyundai       22.750000
# subaru        22.428571
# audi          22.027778
# toyota        21.720588
# pontiac       21.700000
# nissan        21.346154
# chevrolet     18.447368
# ford          16.680000
# mercury       15.625000
# jeep          15.562500
# dodge         15.540541
# lincoln       14.166667
# land rover    14.000000
# Name: average_mileage, dtype: float64

# %%
# honda has best milegae per gallon

# %%
# 16. Do automatic or manual cars have better miles per gallon?
mpg[mpg.transmission.str.contains('auto')].average_mileage.mean() > mpg[mpg.transmission.str.contains("manual")].average_mileage.mean()
# Out:
# False

# %%
# Manual cars have better miles per gallon

# %%
#another way, this is getting abit now
mpg.groupby('is_automatic').mean()["average_mileage"]
# Out:
# is_automatic
# False    22.227273
# True     19.130573
# Name: average_mileage, dtype: float64

# %%
# Exercise III
#1. Use your get_db_url function to help you explore the data from the chipotle database.

db_name = "chipotle"
url = get_db_url_local(username, host, password, db_name)
orders = pd.read_sql("SELECT * FROM orders", url)

#orders.to_csv('orders.csv')
#orders = pd.read_csv('orders.csv')
orders
# Out:
#         id  order_id  quantity                              item_name  \
# 0        1         1         1           Chips and Fresh Tomato Salsa
# 1        2         1         1                                   Izze
# 2        3         1         1                       Nantucket Nectar
# 3        4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4        5         2         2                           Chicken Bowl
# ...    ...       ...       ...                                    ...
# 4617  4618      1833         1                          Steak Burrito
# 4618  4619      1833         1                          Steak Burrito
# 4619  4620      1834         1                     Chicken Salad Bowl
# 4620  4621      1834         1                     Chicken Salad Bowl
# 4621  4622      1834         1                     Chicken Salad Bowl
#
#                                                                      choice_description  \
# ...

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  4622 non-null   int64
#  1   order_id            4622 non-null   int64
#  2   quantity            4622 non-null   int64
#  3   item_name           4622 non-null   object
#  4   choice_description  4622 non-null   object
#  5   item_price          4622 non-null   object
# dtypes: int64(3), object(3)
# memory usage: 216.8+ KB

# %%
#2. What is the total price for each order?

# %%
orders['item_price'] = orders.item_price.str.replace('$', '').astype(float)
# Out:
# /var/folders/yt/n2syrxfn78lfgkf_dg2j4tj80000gn/T/ipykernel_883/4145845266.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   orders['item_price'] = orders.item_price.str.replace('$', '').astype(float)

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  4622 non-null   int64
#  1   order_id            4622 non-null   int64
#  2   quantity            4622 non-null   int64
#  3   item_name           4622 non-null   object
#  4   choice_description  4622 non-null   object
#  5   item_price          4622 non-null   float64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 216.8+ KB

# %%
total_price = orders.groupby('order_id').item_price.sum()
total_price
# Out:
# order_id
# 1       11.56
# 2       16.98
# 3       12.67
# 4       21.00
# 5       13.70
#         ...
# 1830    23.00
# 1831    12.90
# 1832    13.20
# 1833    23.50
# 1834    28.75
# Name: item_price, Length: 1834, dtype: float64

# %%
# 3 What are the most popular 3 items?


orders.groupby("item_name").quantity.sum().sort_values(ascending = False).head(3)
# Out:
# item_name
# Chicken Bowl           761
# Chicken Burrito        591
# Chips and Guacamole    506
# Name: quantity, dtype: int64

# %%
#4. Which item has produced the most revenue?
orders["total_price"] = orders.quantity * orders.item_price
orders.head(2)
# Out:
#    id  order_id  quantity                     item_name choice_description  \
# 0   1         1         1  Chips and Fresh Tomato Salsa                nan
# 1   2         1         1                          Izze       [Clementine]
#
#    item_price  total_price
# 0        2.39         2.39
# 1        3.39         3.39

# %%
orders.groupby("item_name").total_price.sum().sort_values(ascending = False).head(1)
# Out:
# item_name
# Chicken Bowl    8044.63
# Name: total_price, dtype: float64

# %%
# Join the employees and titles DataFrames together.

employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300024 entries, 0 to 300023
# Data columns (total 6 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   emp_no      300024 non-null  int64
#  1   birth_date  300024 non-null  object
#  2   first_name  300024 non-null  object
#  3   last_name   300024 non-null  object
#  4   gender      300024 non-null  object
#  5   hire_date   300024 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 13.7+ MB

# %%
titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443308 entries, 0 to 443307
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   emp_no     443308 non-null  int64
#  1   title      443308 non-null  object
#  2   from_date  443308 non-null  object
#  3   to_date    443308 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 13.5+ MB

# %%
# Join the employees and titles DataFrames together."
employees_titles = employees.merge(titles, left_on = "emp_no", right_on = "emp_no", how = "inner")
employees_titles
employees_titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 443308 entries, 0 to 443307
# Data columns (total 9 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   emp_no      443308 non-null  int64
#  1   birth_date  443308 non-null  object
#  2   first_name  443308 non-null  object
#  3   last_name   443308 non-null  object
#  4   gender      443308 non-null  object
#  5   hire_date   443308 non-null  object
#  6   title       443308 non-null  object
#  7   from_date   443308 non-null  object
#  8   to_date     443308 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 33.8+ MB

# %%
# 6. For each title, find the hire date of the employee that was hired most recently with that title
employees_titles.groupby("title").hire_date.max()
# Out:
# title
# Assistant Engineer    1999-12-24
# Engineer              2000-01-28
# Manager               1992-02-05
# Senior Engineer       2000-01-01
# Senior Staff          2000-01-13
# Staff                 2000-01-12
# Technique Leader      1999-12-31
# Name: hire_date, dtype: object

# %%
# 7. Write the code necessary to create a cross tabulation of the number of titles by department. (Hint: this will involve a combination of SQL code to pull the necessary data and python/pandas code to perform the manipulations.)
db_name = "employees"
url = get_db_url_local(username, host, password, db_name)
pd.read_sql("SHOW TABLES", url)
# Out:
#   Tables_in_employees
# 0         departments
# 1            dept_emp
# 2        dept_manager
# 3           employees
# 4            salaries
# 5              titles

# %%
dept_titles = pd.read_sql(''' SELECT * FROM departments d
                                        JOIN dept_emp de
                                            ON  d.dept_no = de.dept_no
                                        JOIN titles t
                                            ON de.emp_no = t.emp_no
                                        ''', url)
dept_titles
# Out:
#        dept_no         dept_name  emp_no dept_no   from_date     to_date  \
# 0         d009  Customer Service   10011    d009  1990-01-22  1996-11-09
# 1         d009  Customer Service   10038    d009  1989-09-20  9999-01-01
# 2         d009  Customer Service   10038    d009  1989-09-20  9999-01-01
# 3         d009  Customer Service   10049    d009  1992-05-04  9999-01-01
# 4         d009  Customer Service   10049    d009  1992-05-04  9999-01-01
# ...        ...               ...     ...     ...         ...         ...
# 489898    d007             Sales  499986    d007  1985-08-11  9999-01-01
# 489899    d007             Sales  499986    d007  1985-08-11  9999-01-01
# 489900    d007             Sales  499987    d007  1999-12-21  9999-01-01
# 489901    d007             Sales  499988    d007  1988-07-25  2001-10-09
# 489902    d007             Sales  499988    d007  1988-07-25  2001-10-09
#
#         emp_no         title   from_date     to_date
# ...

# %%
pd.crosstab(dept_titles.dept_name, dept_titles.title)
# Out:
# title               Assistant Engineer  Engineer  Manager  Senior Engineer  \
# dept_name
# Customer Service                   298      2362        4             2027
# Development                       7769     58135        2            49326
# Finance                              0         0        2                0
# Human Resources                      0         0        2                0
# Marketing                            0         0        2                0
# Production                        6445     49649        4            42205
# Quality Management                1831     13852        4            11864
# Research                           378      2986        2             2570
# Sales                                0         0        2                0
#
# title               Senior Staff  Staff  Technique Leader
# dept_name
# Customer Service           13925  16150               309
# Development                 1247   1424              7683
# ...
